# %% [markdown]
# <a href="https://colab.research.google.com/github/Daumi-lab08/Analisis-Deret-Waktu/blob/main/Tugas_Kelompok_Minggu_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. Buatlah simulasi deret MA (1) dengan panjang pengamatan 20 dengan nilai parameter $\theta=0.1, \theta=0.3, \theta=0.7, \theta=1.0, \theta=1.5, \theta=2.0$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# A. Simulasi deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=0.1$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=0.1
et=[np.random.normal(0,1)]
ma1_m1=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m1.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m1)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m1), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m1), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m1), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan scatterplot dan plot ACF, deret MA(1) dengan $\theta=0.1$ menunjukkan autokorelasi negatif yang relatif lemah pada lag 1. Secara teoritis, nilai autokorelasi lag 1 adalah $\rho_1=-\theta/(1+\theta^2)$, sehingga untuk $\theta=0.1$ diperoleh nilai sekitar $-0.099$. Sementara itu, autokorelasi pada lag 2 dan lag berikutnya secara teoritis bernilai nol. Hasil simulasi menunjukkan pola yang sejalan dengan teori, meskipun nilai ACF sampel tidak sama persis dengan nilai teoritis karena jumlah pengamatan yang relatif sedikit, yaitu 20 pengamatan.

# %% [markdown]
# B. Simulasikan deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=0.3$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=0.3
et=[np.random.normal(0,1)]
ma1_m2=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m2.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m2)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m2), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m2), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m2), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan scatterplot dan plot ACF, deret MA(1) dengan $\theta=0.3$ menunjukkan autokorelasi negatif pada lag 1. Nilai ACF sampel pada lag 1 terlihat sekitar $-0.25$ dan cukup dekat dengan nilai teoritis sebesar $-0.2752$. Dibandingkan dengan $\theta=0.1$, hubungan negatif pada lag 1 terlihat lebih kuat karena nilai absolut autokorelasinya lebih besar. Sementara itu, pada lag 2 dan lag berikutnya tidak terlihat hubungan yang berarti, sesuai dengan karakteristik teoritis model MA(1).

# %% [markdown]
# C. Simulasi deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=0.7$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=0.7
et=[np.random.normal(0,1)]
ma1_m3=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m3.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m3)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m3), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m3), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m3), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan scatterplot dan plot ACF, deret MA(1) dengan $\theta=0.7$ menunjukkan autokorelasi negatif pada lag 1 yang lebih kuat dibandingkan pada $\theta=0.1$ dan $\theta=0.3$. Nilai ACF sampel pada lag 1 terlihat sekitar $-0.4$ dan cukup mendekati nilai teoritis sebesar $-0.4698$. Sementara itu, pada lag 2 dan lag berikutnya tidak terlihat hubungan yang berarti. Hasil ini menunjukkan bahwa semakin besar nilai $\theta$ dari 0.1 menuju 0.7, nilai absolut autokorelasi lag 1 juga semakin besar.

# %% [markdown]
# D. Simulasi deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=1$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=1
et=[np.random.normal(0,1)]
ma1_m4=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m4.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m4)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m4), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m4), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m4), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan scatterplot dan plot ACF, deret MA(1) dengan $\theta=1.0$ menunjukkan autokorelasi negatif yang cukup kuat pada lag 1. Nilai ACF sampel pada lag 1 terlihat sekitar $-0.42$ dan cukup mendekati nilai teoritis sebesar $-0.5$. Dibandingkan dengan $\theta=0.1$, $\theta=0.3$, dan $\theta=0.7$, nilai absolut autokorelasi lag 1 terus meningkat hingga mencapai nilai teoritis maksimum sebesar $0.5$ ketika $\theta=1.0$. Pada lag 2 dan seterusnya, autokorelasi secara teoritis bernilai nol.

# %% [markdown]
# E. Simulasikan deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=1.5$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=1.5
et=[np.random.normal(0,1)]
ma1_m5=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m5.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m5)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m5), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m5), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m5), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan scatterplot dan plot ACF, deret MA(1) dengan $\theta=1.5$ menunjukkan autokorelasi negatif yang cukup kuat pada lag 1. Nilai ACF sampel pada lag 1 terlihat sekitar $-0.41$ dan cukup mendekati nilai teoritis sebesar $-0.4615$. Namun, dibandingkan dengan $\theta=1.0$, nilai absolut autokorelasi teoritis pada $\theta=1.5$ mulai menurun. Hal ini menunjukkan bahwa peningkatan nilai $\theta$ tidak selalu menyebabkan autokorelasi lag 1 semakin besar. Nilai absolut autokorelasi mencapai maksimum ketika $\theta=1.0$, kemudian menurun ketika $\theta>1$.

# %% [markdown]
# F. Simulasi    deret MA (1) kita lakukan secara manual berdasarkan persamaan proses MA (1) dengan $\theta=2$ dengan panjang pengamatan sebanyak 20

# %%
np.random.seed(120)
theta=2
et=[np.random.normal(0,1)]
ma1_m6=[]
for i in range(20):
    et.append(np.random.normal(0,1))
    ma1_m6.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m6)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m6), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m6), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m6), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan plot pencar dan plot ACF, deret MA(1) dengan $\theta=1.5$ menunjukkan autokorelasi negatif yang cukup kuat pada lag 1. Nilai ACF sampel pada lag 1 terlihat sekitar $-0.41$ dan cukup mendekati nilai teoritis sebesar $-0.4615$. Namun, dibandingkan dengan $\theta=1.0$, nilai absolut autokorelasi teoritis pada $\theta=1.5$ mulai menurun. Hal ini menunjukkan bahwa peningkatan nilai $\theta$ tidak selalu menyebabkan autokorelasi lag 1 semakin besar. Nilai absolut autokorelasi mencapai maksimum ketika $\theta=1.0$, kemudian menurun ketika $\theta>1$.

# %% [markdown]
# Simulasi deret dalam 1 jendela

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
data_ma = [ma1_m1, ma1_m2, ma1_m3, ma1_m4, ma1_m5, ma1_m6]
theta_list = [0.1, 0.3, 0.7, 1.0, 1.5, 2.0]

fig, axes = plt.subplots(2, 3, figsize=(15, 8))

for ax, data, theta in zip(axes.flatten(), data_ma, theta_list):
    ax.plot(data)
    ax.set_title(rf'MA(1), $\theta={theta}$')
    ax.set_xlabel('Waktu')
    ax.set_ylabel(r'$Y_t$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 1 dan bandingkan. Berdasarkan plot ACF tersebut, apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA, kaitkan nilai autokorelasi sampel dengan nilai autokorelasi MA(1) secara teori.)

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8))

plot_acf(ma1_m1, ax=axes[0,0], lags=10, title=r'MA(1), $\theta=0.1$')
plot_acf(ma1_m2, ax=axes[0,1], lags=10, title=r'MA(1), $\theta=0.3$')
plot_acf(ma1_m3, ax=axes[0,2], lags=10, title=r'MA(1), $\theta=0.7$')

plot_acf(ma1_m4, ax=axes[1,0], lags=10, title=r'MA(1), $\theta=1.0$')
plot_acf(ma1_m5, ax=axes[1,1], lags=10, title=r'MA(1), $\theta=1.5$')
plot_acf(ma1_m6, ax=axes[1,2], lags=10, title=r'MA(1), $\theta=2.0$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Buatlah simulasi deret MA (1) dengan parameter $\theta=0.25$ dengan panjang pengamatan 60, 100,150, 300.

# %% [markdown]
# A. Panjang pengamatan 60

# %%
np.random.seed(120)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m7=[]
for i in range(60):
    et.append(np.random.normal(0,1))
    ma1_m7.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m7)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m7), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m7), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m7), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan hasil simulasi MA(1) dengan $\theta=0.25$ dan panjang pengamatan 60, terdapat hubungan negatif pada lag 1 dengan nilai ACF sampel sekitar $-0.32$, yang searah dengan nilai teoritis sebesar $-0.2353$. Pada lag 2 dan lag berikutnya, autokorelasi cenderung berada di sekitar nol. Interval kepercayaan pada plot ACF masih relatif lebar karena jumlah pengamatan yang digunakan belum terlalu besar. Hasil ini nantinya dapat dibandingkan dengan $n=100$, $150$, dan $300$ untuk melihat perubahan lebar interval kepercayaan seiring bertambahnya jumlah pengamatan.

# %% [markdown]
# B. Panjang Pengamatan 100

# %%
np.random.seed(120)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m8=[]
for i in range(100):
    et.append(np.random.normal(0,1))
    ma1_m8.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m8)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m8), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m8), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m8), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan hasil simulasi MA(1) dengan $\theta=0.25$ dan panjang pengamatan 100, terdapat autokorelasi negatif pada lag 1, sedangkan pada lag 2 dan lag berikutnya autokorelasi cenderung berada di sekitar nol. Dibandingkan dengan panjang pengamatan 60, interval kepercayaan pada plot ACF menjadi lebih sempit. Hal ini menunjukkan bahwa bertambahnya jumlah pengamatan dapat meningkatkan ketelitian dalam mengestimasi autokorelasi sampel.

# %% [markdown]
# C. Panjang Pengamatan 150

# %%
np.random.seed(120)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m9=[]
for i in range(150):
    et.append(np.random.normal(0,1))
    ma1_m9.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m9)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m9), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m9), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m9), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan hasil simulasi MA(1) dengan $\theta=0.25$ dan panjang pengamatan 150, diperoleh autokorelasi negatif pada lag 1 yang searah dengan nilai teoritis sebesar $-0.2353$. Pada lag 2 dan lag berikutnya, nilai autokorelasi cenderung berada di sekitar nol. Dibandingkan dengan panjang pengamatan 60 dan 100, interval kepercayaan pada plot ACF semakin sempit. Hal ini menunjukkan bahwa semakin banyak jumlah pengamatan, ketidakpastian dalam estimasi autokorelasi semakin kecil sehingga pola autokorelasi deret dapat terlihat dengan lebih jelas.

# %% [markdown]
# D. Panjang Pengamatan 300

# %%
np.random.seed(120)
theta=0.25
et=[np.random.normal(0,1)]
ma1_m10=[]
for i in range(300):
    et.append(np.random.normal(0,1))
    ma1_m10.append(et[i+1]-theta*et[i])

# %%
plt.figure(figsize=(10,5))
plt.plot(ma1_m10)
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m10), lag=1, c='k')
plt.xlabel(r'$Y_{t-1}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plt.figure(figsize=(6,5))
pd.plotting.lag_plot(pd.DataFrame(ma1_m10), lag=2, c='k')
plt.xlabel(r'$Y_{t-2}$'),plt.ylabel(r'$Y_{t}$')
plt.show()

# %%
plot_acf(np.array(ma1_m10), zero=False)
plt.show()

# %% [markdown]
# Berdasarkan hasil simulasi MA(1) dengan $\theta=0.25$ dan panjang pengamatan 300, diperoleh autokorelasi negatif pada lag 1 dengan nilai ACF sampel sekitar $-0.30$, yang searah dengan nilai teoritis sebesar $-0.2353$. Pada lag 2 dan lag berikutnya, nilai autokorelasi cenderung berada di sekitar nol. Dibandingkan dengan panjang pengamatan yang lebih kecil, interval kepercayaan pada plot ACF semakin sempit. Hal ini menunjukkan bahwa semakin besar jumlah pengamatan, ketidakpastian estimasi autokorelasi semakin kecil sehingga pola autokorelasi MA(1) dapat teridentifikasi dengan lebih jelas.

# %% [markdown]
# Simulasi deret waktu dalam 1 jendela

# %%
data_ma = [ma1_m7, ma1_m8, ma1_m9, ma1_m10]
n_list = [60, 100, 150, 300]

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

for ax, data, n in zip(axes.flatten(), data_ma, n_list):
    ax.plot(data)
    ax.set_title(rf'MA(1), $\theta=0.25$, n={n}')
    ax.set_xlabel('Waktu')
    ax.set_ylabel(r'$Y_t$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 3 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola interval kepercayaan dari nilai autokorelasi berdasarkan panjang observasi.)

# %%
data_ma = [ma1_m7, ma1_m8, ma1_m9, ma1_m10]
n_list = [60, 100, 150, 300]

fig, axes = plt.subplots(2, 2, figsize=(14, 8))

for ax, data, n in zip(axes.flatten(), data_ma, n_list):
    plot_acf(data, ax=ax, lags=20,
             title=rf'MA(1), $\theta=0.25$, n={n}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5. Buatlah simulasi deret MA (2) dengan panjang pengamatan 50 dengan parameter:
#
#    a. $\theta_1=0.3, \theta_2=0.8$
#
#    b. $\theta_1=-0.3, \theta_2=0.8$
#
#    c. $\theta_1=0.3, \theta_2=-0.8$
#
#    d. $\theta_1=-0.3, \theta_2=-0.8$

# %%
SUMLAST2DIGIT = 33+50+37
print(SUMLAST2DIGIT)
# Out:
# 120

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import warnings
warnings.filterwarnings("ignore")

# %%
# Deklarasi Nilai Konstan
THETA1A = 0.3
THETA2A = 0.8
THETA1B = -0.3
THETA2B = 0.8
THETA1C = 0.3
THETA2C = -0.8
THETA1D = -0.3
THETA2D = -0.8
NSAMPLE = 50

# %%
# Fungsi Pembangkitan Data
def generate_ma2_sample(theta1, theta2, nsample):
  np.random.seed(SUMLAST2DIGIT)
  ar = np.array([1])
  ma2 = np.array([1, -theta1, -theta2])
  ma2_obj = ArmaProcess(ar, ma2)
  ma2_sample = ma2_obj.generate_sample(nsample=nsample)
  return ma2_sample

# %%
data_a = generate_ma2_sample(THETA1A, THETA2A, NSAMPLE)
data_b = generate_ma2_sample(THETA1B, THETA2B, NSAMPLE)
data_c = generate_ma2_sample(THETA1C, THETA2C, NSAMPLE)
data_d = generate_ma2_sample(THETA1D, THETA2D, NSAMPLE)

# %%
fig, axs = plt.subplots(2,2)
fig.suptitle('Simulasi deret MA(2)')
axs[0,0].plot(data_a)
axs[0,0].set_title(r'$\theta_1=0.3, \theta_2=0.8$')
axs[0,1].plot(data_b)
axs[0,1].set_title(r'$\theta_1=-0.3, \theta_2=0.8$')
axs[1,0].plot(data_c)
axs[1,0].set_title(r'$\theta_1=0.3, \theta_2=-0.8$')
axs[1,1].plot(data_d)
axs[1,1].set_title(r'$\theta_1=-0.3, \theta_2=-0.8$')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 5 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 dan 2 dari deret MA(2)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA.)

# %%
def plot_acf_and_lag_scatter(data, lags_for_scatter, title_prefix, acf_lags=10):
    num_scatter_lags = len(lags_for_scatter)
    num_plots = 1 + num_scatter_lags # 1 for ACF, rest for scatter

    fig, axs = plt.subplots(1, num_plots, figsize=(5 * num_plots, 5))
    if num_plots == 1:
        axs = [axs] # Ensure axs is iterable even for a single subplot

    fig.suptitle(title_prefix)

    # Plot ACF in the first subplot
    plot_acf(data, ax=axs[0], lags=acf_lags)
    axs[0].set_title('ACF')
    axs[0].set_xlabel('Lag')
    axs[0].set_ylabel('Autocorrelation')

    # Plot lag scatters in the remaining subplots
    for i, lag in enumerate(lags_for_scatter):
        pd.plotting.lag_plot(pd.DataFrame(data), lag=lag, c='k', ax=axs[i+1])
        axs[i+1].set_title(f'Lag {lag}')
        axs[i+1].set_xlabel(f'$Y_{{t-{lag}}}$')
        axs[i+1].set_ylabel('$Y_t$')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust rect to make space for suptitle
    plt.show()

# %%
lags_for_scatter = [1, 2, 3]

plot_acf_and_lag_scatter(data_a, lags_for_scatter, r'Plot untuk $\theta_1=0.3, \theta_2=0.8$')
plot_acf_and_lag_scatter(data_b, lags_for_scatter, r'Plot untuk $\theta_1=-0.3, \theta_2=0.8$')
plot_acf_and_lag_scatter(data_c, lags_for_scatter, r'Plot untuk $\theta_1=0.3, \theta_2=-0.8$')
plot_acf_and_lag_scatter(data_d, lags_for_scatter, r'Plot untuk $\theta_1=-0.3, \theta_2=-0.8$')

# %% [markdown]
# <h1>Interpretasi plot</h1>
# Sesuai dengan persamaan $Y_t = e_t-\theta_1 e_{t-1} - \theta_2 e_{t-2}$ yang memiliki ordo 2, autokorelasi selalu signifikan pada $lag=2$ yang berarti nilai $Y_t$ dipengaruhi kuat oleh $e_{t-1}$ dan $e_{t-2}$. Begitu juga dengan nilai $\rho_2$ ($Autokorelasi$ untuk $lag=2$) yang selalu memiliki arah yang berlawanan terhadap $\theta$, selaras dengan persamaan $\rho_2 = \frac{-\theta_2}{1+\theta^2_1+\theta^2_2}$.

# %% [markdown]
# ## 7. Buatlah simulasi deret AR (1) 100 pengamatan dengan nilai parameter $\phi=0.3, \phi=0.9, \phi=-0.3, \phi=-0.9$

# %%
# ============================================================
# SIMULASI DAN ANALISIS AR(1)
# phi = 0.3, 0.9, -0.3, -0.9
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox


# ============================================================
# 1. FUNGSI SIMULASI AR(1)
# ============================================================

def simulate_ar1(phi, n=100, sigma=1):
    """
    Simulasi proses AR(1):

        Y_t = phi * Y_(t-1) + epsilon_t

    dengan:
        Y_0 ~ Uniform(0,1)
        epsilon_t ~ Normal(0, sigma2)
    """

    y = [0.0] * n

    # Nilai awal
    y[0] = np.random.uniform(0, 1)

    # Random error
    epsilon = np.random.normal(0, sigma, n)

    # Proses AR(1)
    for t in range(1, n):
        y[t] = phi * y[t-1] + epsilon[t]

    return np.array(y)


# ============================================================
# 2. PARAMETER DAN SEED
# ============================================================

np.random.seed(120)

phis = [0.3, 0.9, -0.3, -0.9]

n = 100
sigma = 1


# ============================================================
# 3. SIMULASI DATA HANYA SATU KALI
# ============================================================

series = {}

for phi in phis:

    series[phi] = simulate_ar1(
        phi=phi,
        n=n,
        sigma=sigma
    )


# ============================================================
# 4. MEMBUAT DATAFRAME HASIL SIMULASI
# ============================================================

df_simulasi = pd.DataFrame({
    f'Y_phi_{phi}': series[phi]
    for phi in phis
})

df_simulasi.index = np.arange(1, n + 1)
df_simulasi.index.name = 'Waktu'


print("DATA SIMULASI AR(1)")
print("=" * 70)

display(df_simulasi.head(10))
# Out:
# DATA SIMULASI AR(1)
# ======================================================================
#        Y_phi_0.3  Y_phi_0.9  Y_phi_-0.3  Y_phi_-0.9
# Waktu
# 1       0.677956   0.540624    0.710478    0.978919
# 2       0.449161  -0.134640   -1.458689   -0.574584
# 3      -2.545092  -0.739178   -0.789513    0.105536
# 4      -2.304903  -2.107218   -1.784553   -0.016480
# 5      -0.413331  -1.041068    0.341018    0.826333
# 6       0.958213  -2.761201    1.618191   -1.057728
# 7      -0.366700  -2.409139    0.160564    2.346669
# 8      -0.927036  -3.749934   -0.601956   -2.832771
# 9      -0.087512  -3.169987    1.562847    5.094655
# 10     -0.588685  -2.660937    0.576473   -4.321364

# %%
# ============================================================
# 5. PLOT DERET WAKTU
# ============================================================

fig, axes = plt.subplots(
    4, 1,
    figsize=(12, 14)
)

for ax, phi in zip(axes, phis):

    y = series[phi]

    ax.plot(
        range(1, n + 1),
        y
    )

    ax.set_title(
        f'Simulasi AR(1), φ = {phi}'
    )

    ax.set_xlabel('Waktu')
    ax.set_ylabel(r'$Y_t$')

    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
#============================================================
# 6. LAG PLOT LAG 1 DAN LAG 2
# ============================================================

fig, axes = plt.subplots(
    4, 2,
    figsize=(12, 16)
)

for i, phi in enumerate(phis):

    y = series[phi]

    # -----------------------------
    # Lag 1
    # -----------------------------

    axes[i, 0].scatter(
        y[:-1],
        y[1:]
    )

    axes[i, 0].set_title(
        f'Lag Plot 1, φ = {phi}'
    )

    axes[i, 0].set_xlabel(
        r'$Y_{t-1}$'
    )

    axes[i, 0].set_ylabel(
        r'$Y_t$'
    )

    axes[i, 0].grid(alpha=0.3)


    # -----------------------------
    # Lag 2
    # -----------------------------

    axes[i, 1].scatter(
        y[:-2],
        y[2:]
    )

    axes[i, 1].set_title(
        f'Lag Plot 2, φ = {phi}'
    )

    axes[i, 1].set_xlabel(
        r'$Y_{t-2}$'
    )

    axes[i, 1].set_ylabel(
        r'$Y_t$'
    )

    axes[i, 1].grid(alpha=0.3)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 7 dan bandingkan. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(1)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)

# %%
#============================================================
# 7. PLOT ACF DAN PACF
# ============================================================

fig, axes = plt.subplots(
    4, 2,
    figsize=(12, 16)
)

for i, phi in enumerate(phis):

    y = series[phi]

    # -----------------------------
    # ACF
    # -----------------------------

    plot_acf(
        y,
        lags=20,
        zero=False,
        ax=axes[i, 0]
    )

    axes[i, 0].set_title(
        f'ACF AR(1), φ = {phi}'
    )

    axes[i, 0].set_xlabel('Lag')
    axes[i, 0].set_ylabel('ACF')


    # -----------------------------
    # PACF
    # -----------------------------

    plot_pacf(
        y,
        lags=20,
        zero=False,
        method='ywm',
        ax=axes[i, 1]
    )

    axes[i, 1].set_title(
        f'PACF AR(1), φ = {phi}'
    )

    axes[i, 1].set_xlabel('Lag')
    axes[i, 1].set_ylabel('PACF')


plt.tight_layout()
plt.show()


# ============================================================
# 8. TABEL ACF DAN PACF
# ============================================================

lags = 20

hasil_acf_pacf = []

for phi in phis:

    y = series[phi]

    acf_values = acf(
        y,
        nlags=lags,
        fft=False
    )

    pacf_values = pacf(
        y,
        nlags=lags,
        method='ywm'
    )

    for lag in range(1, lags + 1):

        hasil_acf_pacf.append({

            'Phi': phi,

            'Lag': lag,

            'ACF_Simulasi':
                acf_values[lag],

            'ACF_Teoritis':
                phi ** lag,

            'PACF_Simulasi':
                pacf_values[lag],

            'Selisih_ACF':
                acf_values[lag] - phi ** lag
        })


df_acf_pacf = pd.DataFrame(
    hasil_acf_pacf
)

df_acf_pacf = df_acf_pacf.round(4)


print("HASIL ACF DAN PACF")
print("=" * 70)

display(df_acf_pacf)


# ============================================================
# 9. ESTIMASI AR(1) DAN RESIDUAL
# ============================================================

hasil_model = {}

for phi in phis:

    y = series[phi]

    model = AutoReg(
        y,
        lags=1,
        trend='n',
        old_names=False
    ).fit()

    residual = model.resid

    hasil_model[phi] = {
        'model': model,
        'residual': residual
    }

    print("=" * 70)
    print(f"AR(1), φ = {phi}")
    print("=" * 70)

    print(
        f"Koefisien AR(1) estimasi : "
        f"{model.params[0]:.4f}"
    )

    print(
        f"Koefisien AR(1) teoritis : "
        f"{phi:.4f}"
    )


# ============================================================
# 10. UJI LJUNG-BOX LAG 1-20
# ============================================================

hasil_ljungbox = {}

for phi in phis:

    residual = hasil_model[phi]['residual']

    lb = acorr_ljungbox(
        residual,
        lags=range(1, 21),
        return_df=True
    )

    # Jadikan lag sebagai kolom
    lb = lb.reset_index()

    # Pastikan nama kolom lag
    lb = lb.rename(
        columns={'index': 'Lag'}
    )

    # Tambahkan phi
    lb['Phi'] = phi

    # Susun kolom
    lb = lb[
        [
            'Phi',
            'Lag',
            'lb_stat',
            'lb_pvalue'
        ]
    ]

    hasil_ljungbox[phi] = lb


# ============================================================
# 11. GABUNGKAN HASIL LJUNG-BOX
# ============================================================

df_ljungbox = pd.concat(
    hasil_ljungbox.values(),
    ignore_index=True
)

df_ljungbox = df_ljungbox.round(4)


print("=" * 70)
print("HASIL UJI LJUNG-BOX")
print("=" * 70)

display(df_ljungbox)


# ============================================================
# 12. TABEL KEPUTUSAN LJUNG-BOX
# ============================================================

alpha = 0.05

df_ljungbox['Keputusan'] = np.where(
    df_ljungbox['lb_pvalue'] < alpha,
    'Tolak H0',
    'Gagal menolak H0'
)

df_ljungbox['Keterangan'] = np.where(
    df_ljungbox['lb_pvalue'] < alpha,
    'Ada autokorelasi residual',
    'Tidak ada bukti autokorelasi residual'
)


print("=" * 70)
print("KEPUTUSAN UJI LJUNG-BOX")
print("=" * 70)

display(df_ljungbox)


# ============================================================
# 13. MENAMPILKAN HANYA LAG YANG SIGNIFIKAN
# ============================================================

print("=" * 70)
print("LAG DENGAN p-value < 0.05")
print("=" * 70)

for phi in phis:

    lb = hasil_ljungbox[phi]

    signifikan = lb[
        lb['lb_pvalue'] < alpha
    ]

    print(f"\nφ = {phi}")

    if len(signifikan) == 0:

        print(
            "Tidak terdapat autokorelasi residual "
            "yang signifikan pada lag 1-20."
        )

    else:

        display(
            signifikan[
                [
                    'Lag',
                    'lb_stat',
                    'lb_pvalue'
                ]
            ]
        )


# ============================================================
# 14. PLOT p-value LJUNG-BOX
# ============================================================

plt.figure(figsize=(12, 7))

for phi in phis:

    lb = hasil_ljungbox[phi]

    plt.plot(
        lb['Lag'],
        lb['lb_pvalue'],
        marker='o',
        label=f'φ = {phi}'
    )


# Garis batas signifikansi
plt.axhline(
    y=0.05,
    linestyle='--',
    label='Batas signifikansi 0,05'
)

plt.xlabel('Lag')
plt.ylabel('p-value Ljung–Box')

plt.title(
    'p-value Uji Ljung–Box Residual AR(1)'
)

plt.xticks(
    range(1, 21)
)

plt.ylim(
    0,
    1
)

plt.grid(alpha=0.3)

plt.legend()

plt.tight_layout()

plt.show()
# Out:
# HASIL ACF DAN PACF
# ======================================================================
#     Phi  Lag  ACF_Simulasi  ACF_Teoritis  PACF_Simulasi  Selisih_ACF
# 0   0.3    1        0.2491        0.3000         0.2491      -0.0509
# 1   0.3    2       -0.1988        0.0900        -0.2781      -0.2888
# 2   0.3    3       -0.2252        0.0270        -0.1071      -0.2522
# 3   0.3    4        0.0571        0.0081         0.1173       0.0490
# 4   0.3    5        0.0528        0.0024        -0.0831       0.0504
# ..  ...  ...           ...           ...            ...          ...
# 75 -0.9   16        0.2753        0.1853        -0.1359       0.0900
# 76 -0.9   17       -0.2399       -0.1668         0.0496      -0.0731
# 77 -0.9   18        0.1675        0.1501        -0.1988       0.0174
# 78 -0.9   19       -0.0919       -0.1351         0.1389       0.0432
# 79 -0.9   20        0.0269        0.1216         0.0108      -0.0947
#
# [80 rows x 6 columns]
# ======================================================================
# AR(1), φ = 0.3
# ======================================================================
# Koefisien AR(1) estimasi : 0.2665
# Koefisien AR(1) teoritis : 0.3000
# ======================================================================
# AR(1), φ = 0.9
# ======================================================================
# Koefisien AR(1) estimasi : 0.8599
# Koefisien AR(1) teoritis : 0.9000
# ======================================================================
# AR(1), φ = -0.3
# ======================================================================
# Koefisien AR(1) estimasi : -0.2067
# Koefisien AR(1) teoritis : -0.3000
# ======================================================================
# AR(1), φ = -0.9
# ======================================================================
# Koefisien AR(1) estimasi : -0.9430
# Koefisien AR(1) teoritis : -0.9000
# ======================================================================
# HASIL UJI LJUNG-BOX
# ======================================================================
#     Phi  Lag  lb_stat  lb_pvalue
# 0   0.3    1   0.3357     0.5623
# 1   0.3    2   5.0414     0.0804
# 2   0.3    3   9.4861     0.0235
# 3   0.3    4  10.8264     0.0286
# 4   0.3    5  10.8793     0.0538
# ..  ...  ...      ...        ...
# 75 -0.9   16  17.8006     0.3357
# 76 -0.9   17  24.5056     0.1063
# 77 -0.9   18  25.3881     0.1146
# 78 -0.9   19  25.5728     0.1425
# 79 -0.9   20  27.1589     0.1309
#
# [80 rows x 4 columns]
# ======================================================================
# KEPUTUSAN UJI LJUNG-BOX
# ======================================================================
#     Phi  Lag  lb_stat  lb_pvalue         Keputusan  \
# 0   0.3    1   0.3357     0.5623  Gagal menolak H0
# 1   0.3    2   5.0414     0.0804  Gagal menolak H0
# 2   0.3    3   9.4861     0.0235          Tolak H0
# 3   0.3    4  10.8264     0.0286          Tolak H0
# 4   0.3    5  10.8793     0.0538  Gagal menolak H0
# ..  ...  ...      ...        ...               ...
# 75 -0.9   16  17.8006     0.3357  Gagal menolak H0
# 76 -0.9   17  24.5056     0.1063  Gagal menolak H0
# 77 -0.9   18  25.3881     0.1146  Gagal menolak H0
# 78 -0.9   19  25.5728     0.1425  Gagal menolak H0
# 79 -0.9   20  27.1589     0.1309  Gagal menolak H0
#
#                                Keterangan
# 0   Tidak ada bukti autokorelasi residual
# 1   Tidak ada bukti autokorelasi residual
# 2               Ada autokorelasi residual
# 3               Ada autokorelasi residual
# 4   Tidak ada bukti autokorelasi residual
# ..                                    ...
# 75  Tidak ada bukti autokorelasi residual
# 76  Tidak ada bukti autokorelasi residual
# 77  Tidak ada bukti autokorelasi residual
# 78  Tidak ada bukti autokorelasi residual
# 79  Tidak ada bukti autokorelasi residual
#
# [80 rows x 6 columns]
# ======================================================================
# LAG DENGAN p-value < 0.05
# ======================================================================
#
# φ = 0.3
#    Lag    lb_stat  lb_pvalue
# 2    3   9.486067   0.023480
# 3    4  10.826350   0.028586
# φ = 0.9
#     Lag    lb_stat  lb_pvalue
# 14   15  26.420078   0.033832
# 15   16  26.649707   0.045545
# 17   18  32.813618   0.017578
# 18   19  32.998488   0.024050
# 19   20  35.099856   0.019579
# φ = -0.3
# Tidak terdapat autokorelasi residual yang signifikan pada lag 1-20.
#
# φ = -0.9
# Tidak terdapat autokorelasi residual yang signifikan pada lag 1-20.

# %% [markdown]
# ## 9. Berdasarkan plot ACF dan PACF pada nomor 8, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.

# %% [markdown]
# Berdasarkan plot ACF dan PACF, keempat deret menunjukkan karakteristik model AR(1). ACF pada masing-masing deret mengalami tailing off, sedangkan PACF menunjukkan cut-off setelah lag 1. Oleh karena itu, model yang disarankan untuk adalah AR(1). Nilai positif pada psi menghasilkan autokorelasi positif, sedangkan nilai negatif menghasilkan autokorelasi yang berganti tanda. Semakin besar nilai absolut psi , semakin kuat dan semakin persisten ketergantungan antar waktu.

# %% [markdown]
# ## 10. Buatlah simulasi deret AR (2) dengan panjang pengamatan 100 dengan parameter:
#
#    a. $\phi_1=1.5, \phi_2=-0.5$
#
#    b. $\phi_1=0.75, \phi_2=-0.25$
#
#    c. $\phi_1=1, \phi_2=-0.25$
#
#    d. $\phi_1=0.5, \phi_2=-0.75$

# %%
# ============================================================
# SIMULASI AR(2)
# ============================================================

import numpy as np
import matplotlib.pyplot as plt


# ============================================================
# 1. Fungsi simulasi AR(2)
# ============================================================

def simulate_ar2(phi1, phi2, n=100, sigma=1):
    """
    Simulasi proses AR(2) berdasarkan formula user:
        Y_t = phi1 * Y_(t-1) + phi2 * Y_(t-2) + epsilon_t
    dengan:
        Y_0, Y_1 ~ Uniform(0,1)
        epsilon_t ~ Normal(0, sigma^2)
    """
    # Initialize with two random uniform values for Y_0 and Y_1
    y = [np.random.uniform(0, 1), np.random.uniform(0, 1)]

    # Generate the rest of the series
    for _ in range(n - 2): # Loop n-2 times to get total n observations (2 initial + n-2 appended)
        # Use y[-1] for Y_(t-1) and y[-2] for Y_(t-2) for current t
        y.append(phi1 * y[-1] + phi2 * y[-2] + np.random.normal(0, sigma))

    return np.array(y)


# ============================================================
# 2. Parameter AR(2)
# ============================================================

parameters = {
    'a': (1.5, -0.5),
    'b': (0.75, -0.25),
    'c': (1.0, -0.25),
    'd': (0.5, -0.75)
}


# ============================================================
# 3. Seed agar hasil dapat direplikasi
# ============================================================

np.random.seed(120)


# ============================================================
# 4. Simulasi data
# ============================================================

series_ar2 = {}

for kode, (phi1, phi2) in parameters.items():

    series_ar2[kode] = simulate_ar2(
        phi1=phi1,
        phi2=phi2,
        n=100,
        sigma=1
    )


# ============================================================
# 5. Plot hasil simulasi
# ============================================================

fig, axes = plt.subplots(
    4, 1,
    figsize=(12, 14)
)


for ax, (kode, (phi1, phi2)) in zip(
    axes,
    parameters.items()
):

    y = series_ar2[kode]

    ax.plot(
        range(1, 101),
        y
    )

    ax.set_title(
        f'AR(2) {kode}: '
        f'φ₁ = {phi1}, φ₂ = {phi2}'
    )

    ax.set_xlabel('Waktu')
    ax.set_ylabel(r'$Y_t$')

    ax.grid(alpha=0.3)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 10. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(2)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)

# %%
# ============================================================
# PLOT ACF DAN PACF AR(2)
# Menggunakan data simulasi yang sudah tersimpan
# ============================================================

import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf


# Parameter AR(2)
parameters = {
    'a': (1.5, -0.5),
    'b': (0.75, -0.25),
    'c': (1.0, -0.25),
    'd': (0.5, -0.75)
}


# ============================================================
# Plot ACF dan PACF
# ============================================================

fig, axes = plt.subplots(
    4, 2,
    figsize=(12, 16)
)

for i, (kode, (phi1, phi2)) in enumerate(parameters.items()):

    # Mengambil data simulasi yang SUDAH dibuat
    y = series_ar2[kode]

    # -----------------------------
    # ACF
    # -----------------------------
    plot_acf(
        y,
        lags=20,
        zero=False,
        ax=axes[i, 0]
    )

    axes[i, 0].set_title(
        f'ACF AR(2) {kode}: '
        f'φ₁={phi1}, φ₂={phi2}'
    )

    axes[i, 0].set_xlabel('Lag')
    axes[i, 0].set_ylabel('ACF')


    # -----------------------------
    # PACF
    # -----------------------------
    plot_pacf(
        y,
        lags=20,
        zero=False,
        method='ywm',
        ax=axes[i, 1]
    )

    axes[i, 1].set_title(
        f'PACF AR(2) {kode}: '
        f'φ₁={phi1}, φ₂={phi2}'
    )

    axes[i, 1].set_xlabel('Lag')
    axes[i, 1].set_ylabel('PACF')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Berdasarkan plot ACF dan PACF pada nomor 11, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.

# %% [markdown]
# Model yang sesuai yaitu:
#
# a	1.5	-0.5 : ARIMA(1,1,0)
#
# b	0.75	-0.25	: AR(2)
#
# c	1.00	-0.25	: AR(2)
#
# d	0.50	-0.75	: AR(2)

# %% [markdown]
# Plot ACF dan PACF pada model (a) dengan parameter phi : (1.5, -0.5)

# %%
y_a = series_ar2['a']

# First differencing
dy_a = np.diff(y_a)

# Plot ACF dan PACF setelah differencing
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

plot_acf(dy_a, lags=20, zero=False, ax=axes[0])
axes[0].set_title('ACF ΔY - Model (a)')

plot_pacf(dy_a, lags=20, zero=False, method='ywm', ax=axes[1])
axes[1].set_title('PACF ΔY - Model (a)')

plt.tight_layout()
plt.show()
